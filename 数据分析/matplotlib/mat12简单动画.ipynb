# %%
import numpy as np
import matplotlib.pyplot as mp
import matplotlib.animation as ma

def update(number):
	print(number)

mp.figure("A")
a=ma.FuncAnimation(mp.gcf(), update, interval=30) # number参数是指被调用的次数
mp.show()

# %%
n = 100
balls = np.zeros(n, dtype=[
	('position', 'f8', 2), 
	('size', 'f8', 1), 
	('growth', 'f8', 1), 
	('color', 'f8', 4)])
# Out:
# C:\Users\ZXC\AppData\Local\Temp\ipykernel_2468\2243209606.py:2: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   balls = np.zeros(n, dtype=[

# %%
balls_type = np.dtype(  # 这种方式更简单
    {'names':['position', 'size', 'growth', 'color'],
    'formats':['2f8','f8','f8','4f8']
})

# %%
balls2 = np.zeros(100,dtype=balls_type)
balls2

# %%
balls2['position'] = np.random.uniform(0.0, 1.0,(100, 2))
balls2['size'] = np.random.uniform(0,1,100)
balls2['growth']=np.random.uniform(0,1,100)
balls2['color'] = np.random.uniform(0,1,(100,4))

# %%
mp.scatter(balls2['position'][:,0],balls2['position'][:,1],s=balls2['size']*100,color=balls2['color'])

# %%
mp.figure(2)
def update(number):
    print(number)
anim = ma.FuncAnimation(mp.gcf(),update,interval=30) # 必须用一个变量接收一下，避免立即被销毁
mp.show()
