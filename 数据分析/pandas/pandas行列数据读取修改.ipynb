# %%
from IPython.core.interactiveshell import InteractiveShell
import pandas as pd, numpy as np
import openpyxl
InteractiveShell.ast_node_interactivity = 'all'

# %%
df = pd.read_csv('new_team.csv')

# %%
df
type(df)
# Out:
#        name team  Q1  Q2  Q3  Q4
# 0     Aaron    A  96  75  55   8
# 1       Ack    A  57  60  18  84
# 2      Acob    B  61  95  94   8
# 3      Adam    C  90  32  47  39
# 4     Aiden    D  20  31  62  68
# ..      ...  ...  ..  ..  ..  ..
# 95     Toby    A  52  27  17  68
# 96    Tommy    C  29  44  28  76
# 97    Tyler    A  75  16  44  63
# 98  William    C  80  68   3  26
# 99  Zachary    E  12  71  85  93
#
# [100 rows x 6 columns]
# pandas.core.frame.DataFrame

# %%
df.loc[1:9,'Q1':'Q2']
# Out:
#    Q1  Q2
# 1  57  60
# 2  61  95
# 3  90  32
# 4  20  31
# 5  85  38
# 6  79  82
# 7  14  70
# 8  91  76
# 9  83  89

# %%
df.loc[98,'Q4'] = 1999

# %%
df
# Out:
#        name team  Q1  Q2  Q3    Q4
# 0     Aaron    A  96  75  55     8
# 1       Ack    A  57  60  18    84
# 2      Acob    B  61  95  94     8
# 3      Adam    C  90  32  47    39
# 4     Aiden    D  20  31  62    68
# ..      ...  ...  ..  ..  ..   ...
# 95     Toby    A  52  27  17    68
# 96    Tommy    C  29  44  28    76
# 97    Tyler    A  75  16  44    63
# 98  William    C  80  68   3  1999
# 99  Zachary    E  12  71  85    93
#
# [100 rows x 6 columns]

# %%
df['Q5'] = np.arange(start=100,stop=0,step=-1)
df
# Out:
#        name team  Q1  Q2  Q3    Q4   Q5
# 0     Aaron    A  96  75  55     8  100
# 1       Ack    A  57  60  18    84   99
# 2      Acob    B  61  95  94     8   98
# 3      Adam    C  90  32  47    39   97
# 4     Aiden    D  20  31  62    68   96
# ..      ...  ...  ..  ..  ..   ...  ...
# 95     Toby    A  52  27  17    68    5
# 96    Tommy    C  29  44  28    76    4
# 97    Tyler    A  75  16  44    63    3
# 98  William    C  80  68   3  1999    2
# 99  Zachary    E  12  71  85    93    1
#
# [100 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['name', 'team', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5'], dtype='object')

# %%
df['Q5'].rename('Q55',inplace=True)
# Out:
# 0     100
# 1      99
# 2      98
# 3      97
# 4      96
#      ...
# 95      5
# 96      4
# 97      3
# 98      2
# 99      1
# Name: Q55, Length: 100, dtype: int64

# %%
df
# Out:
#        name team  Q1  Q2  Q3    Q4   Q5
# 0     Aaron    A  96  75  55     8  100
# 1       Ack    A  57  60  18    84   99
# 2      Acob    B  61  95  94     8   98
# 3      Adam    C  90  32  47    39   97
# 4     Aiden    D  20  31  62    68   96
# ..      ...  ...  ..  ..  ..   ...  ...
# 95     Toby    A  52  27  17    68    5
# 96    Tommy    C  29  44  28    76    4
# 97    Tyler    A  75  16  44    63    3
# 98  William    C  80  68   3  1999    2
# 99  Zachary    E  12  71  85    93    1
#
# [100 rows x 7 columns]

# %%
arr = np.random.randn(5,8)
arr
# Out:
# array([[ 0.41061992, -0.38235272, -0.57044057,  0.14385568, -1.72926341,
#         -1.03819761,  0.44096342, -0.25136191],
#        [-0.45196889,  0.37490152,  0.98324513, -0.58778676,  1.40413894,
#          0.16964699, -0.69556538, -1.8825967 ],
#        [-1.00413552, -0.24165396, -0.26566382,  0.09994564, -0.61722068,
#          1.9673282 , -0.63722419,  1.57174597],
#        [ 0.16453923, -1.26891753,  0.37223592, -1.02752121, -0.2039328 ,
#          1.1690709 ,  0.12532387,  1.10324833],
#        [ 1.34386413, -0.38726942,  0.47134937,  0.10079777, -0.16426184,
#         -0.56694003,  0.99222191, -0.07784149]])

# %%
arr[...,1]
# Out:
# array([ 1.30183325, -0.3422134 ,  0.40066741, -1.17141442, -0.96729976])

# %%
arr[...][1]
# Out:
# array([-0.45196889,  0.37490152,  0.98324513, -0.58778676,  1.40413894,
#         0.16964699, -0.69556538, -1.8825967 ])

# %%
arr[(arr>0)]
# Out:
# array([0.41061992, 0.14385568, 0.44096342, 0.37490152, 0.98324513,
#        1.40413894, 0.16964699, 0.09994564, 1.9673282 , 1.57174597,
#        0.16453923, 0.37223592, 1.1690709 , 0.12532387, 1.10324833,
#        1.34386413, 0.47134937, 0.10079777, 0.99222191])

# %%
_.shape
# Out:
# (19,)

# %%
x = np.linspace(0,np.pi*4,num=1000)  
y = (np.tan(x))
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show()
