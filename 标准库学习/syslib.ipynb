# %%
import sys

# %%
sys.argv
# Out:
# ['c:\\Users\\ZXC\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\ipykernel_launcher.py',
#  '--ip=127.0.0.1',
#  '--stdin=9008',
#  '--control=9006',
#  '--hb=9005',
#  '--Session.signature_scheme="hmac-sha256"',
#  '--Session.key=b"67aff46b-5be2-48e1-a110-f0878db5d836"',
#  '--shell=9007',
#  '--transport="tcp"',
#  '--iopub=9009',
#  '--f=c:\\Users\\ZXC\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-20292Ro3jm5rrrRqx.json']

# %%
sys.platform
# Out:
# 'win32'

# %%
sys.getwindowsversion()  # 当前Windows系统版本号
# Out:
# sys.getwindowsversion(major=10, minor=0, build=22000, platform=2, service_pack='')

# %%
sys.exit()

# %%
sys?
